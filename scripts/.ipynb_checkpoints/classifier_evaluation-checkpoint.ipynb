# %%
import os
os.chdir("/home/jparkinson/Documents/Wang_Lab_Projects/CBX1/CBX1_GITHUB/cbx1_protein_engineering/scripts")

# %%
import train_models, numpy as np
from importlib import reload
reload(train_models)
from train_models import load_data
import evaluate_classifiers
reload(evaluate_classifiers)
from evaluate_classifiers import calc_RH04_auc_train_test, evaluate_subsampling

# %%
calc_RH04_auc_train_test()
# Out:
# Training set ord AUC: 0.9433028555736108
# Test set ord AUC: 0.9326090183597368
# Training set enrich AUC: 0.6950246821594279
# Test set enrich AUC: 0.6788705109302001
# Training set bin AUC: 0.9183664286622456
# Test set bin AUC: 0.8930243652946056
# Training set rf AUC: 0.8923901844924618
# Test set rf AUC: 0.8420394813187948

# %%
calc_RH04_auc_train_test(rh03_only=True)
# Out:
# Training set ord AUC: 0.8616337813819063
# Test set ord AUC: 0.8536230091476574
# Training set enrich AUC: 0.6950246821594279
# Test set enrich AUC: 0.6788705109302001
# Training set bin AUC: 0.8512049712776112
# Test set bin AUC: 0.8325644494036655
# Training set rf AUC: 0.7953838818724593
# Test set rf AUC: 0.7779403560112425

# %%
evaluate_subsampling()
# Out:
# Current loss: 2.9604556560516357
# Current loss: 2.562243938446045
# Current loss: 2.35612154006958
# Current loss: 2.4322798252105713
# Current loss: 2.295964479446411
# Current loss: 2.3199026584625244
# Current loss: 2.358639717102051
# Current loss: 2.1864383220672607
# Current loss: 2.0924434661865234
# Current loss: 2.2560946941375732
# Current loss: 2.234575033187866
# Current loss: 2.214664936065674
# Current loss: 2.0399348735809326
# Current loss: 2.1142349243164062
# Current loss: 2.2933826446533203
# Current loss: 2.1731364727020264
# Current loss: 2.37398362159729
# Current loss: 2.110605239868164
# Current loss: 2.030527114868164
# Current loss: 1.9435769319534302
# Current loss: 2.0305917263031006
# Current loss: 2.0385313034057617
# Current loss: 1.9484986066818237
# Current loss: 2.0579564571380615
# Current loss: 1.9704556465148926
# Current loss: 2.017651319503784
# Current loss: 2.0387301445007324
# Current loss: 2.010897159576416
# ...

# %%
import feature_importance_evaluation
from feature_importance_evaluation import score_known_high_binders
reload(feature_importance_evaluation)
score_known_high_binders()
# Out:
# Ordinal reg scores for known_high_binders:
# tensor([[ 9.8473],
#         [ 9.7362],
#         [10.7917],
#         [ 9.3378],
#         [ 8.9785],
#         [ 8.9969],
#         [10.4568],
#         [ 8.0852],
#         [-0.7624]])
# Percentiles:
# [100.0, 99.99796805786971, 100.0, 99.99796805786971, 99.99390417360914, 99.99390417360914, 100.0, 99.99390417360914, 34.00455155037184]
#
#
# Enrichment scores for known_high_binders:
# [ 1.5326345   1.5980206   1.7545389   1.1663479   1.4205866   1.0506785
#   1.3854853   1.1717694  -0.32111374]
# Percentiles:
# [99.95123338887308, 99.97358475230625, 99.98984028934856, 99.57532409476978, 99.91059454626732, 99.08765798350063, 99.88824318283416, 99.59361157394237, 4.903076360385256]
#
#
# Random forest scores for known_high_binders:
# [0.76365491 0.74565264 0.77623792 0.75028928 0.74717349 0.75585691
#  0.78453572 0.7119879  0.17917815]
# Percentiles:
# ...
